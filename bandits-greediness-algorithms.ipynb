# %% [markdown]
# # Reinforcement learning: Bandits, greediness and optimism

# %%
import numpy as np

class Bandit:
    def __init__(self, mean, var=1):
        self.mean = mean
        self.var = var
        
    def draw(self):
        return np.random.normal(loc=self.mean, scale=np.sqrt(self.var))
    
    
bandit0 = Bandit(0)
bandit1 = Bandit(1)
bandit2 = Bandit(2)

bandits = [bandit0, bandit1, bandit2]

# %% [markdown]
# ## Greedy: totally, epsilon, optimistic starting values

# %%
def play_greedy(bandits, n_times, epsilon=0, start_expectation=0, rate=1):
    n_bandits = len(bandits)
    expectations = [start_expectation] * n_bandits
    values = {i: [] for i in range(n_bandits)}
    if start_expectation > 0:
        values = {i: [(-1, start_expectation, True)] for i in range(n_bandits)}
    for i in range(n_times):
        exploitation = True
        if np.random.uniform() > epsilon:
            max_expectation = max(expectations)
            max_elements_inds = [ind for ind, expectation in enumerate(expectations) if expectation == max_expectation]
            ind = np.random.choice(max_elements_inds)
        else:
            exploitation = False
            ind = np.random.choice(range(n_bandits))
        drawn_value = bandits[ind].draw()
        values[ind].append((i, drawn_value, exploitation))
        expectations[ind] = np.mean([v[1] for v in values[ind]])
        epsilon *= rate
    return values, expectations

# %%
values, expectations = play_greedy(bandits, 100, epsilon=.1)

# %%
values
# Out:
# {0: [(0, 0.518368678718732, True),
#   (1, 0.4179136773165176, True),
#   (2, -1.5155707150686213, True),
#   (53, -1.742410132844397, False)],
#  1: [(3, 0.7133951276241697, True),
#   (4, 0.9789391781996101, True),
#   (5, -0.10155577483718559, True),
#   (6, 0.5610075558267564, True),
#   (7, 2.5538749038837807, True),
#   (8, 2.2804775806389563, True),
#   (9, 0.315853177640287, True),
#   (10, 1.6899454084078076, True),
#   (11, 0.06355614566200218, True),
#   (12, 0.19635567447333724, True),
#   (13, 0.04290867061069459, True),
#   (47, 0.5694019803448793, False),
#   (49, 0.4231884148158679, False),
#   (55, 1.9394613219485746, False),
#   (61, 1.5654901805492558, False),
#   (91, 0.8246961292577035, False)],
#  2: [(14, 1.5840742361733915, False),
#   (15, 1.7527076248644091, True),
#   (16, 0.15720672780640843, True),
#   (17, 4.114251304381272, True),
#   (18, 0.5328633961093829, True),
#   (19, 2.8279929399129493, True),
#   (20, 0.9833882083443748, True),
#   (21, 2.5687132538793582, True),
#   (22, 2.770342685474115, True),
#   (23, 1.8638211870883368, True),
#   (24, 0.38000692966854466, True),
#   (25, 1.3526115008513533, False),
#   (26, 1.9499171611657866, True),
#   (27, 1.69714714512883, True),
#   (28, 2.7268472661788135, True),
#   (29, 2.35937837787049, True),
#   (30, 2.186957942572218, True),
#   (31, 0.6489213174730004, True),
#   (32, 1.263401395990825, True),
#   (33, 3.678156430644007, True),
#   (34, 1.7601586528323458, False),
#   (35, 2.9200823977243457, True),
#   (36, 2.3132453047774275, True),
#   (37, 0.8177540657827056, True),
#   (38, 1.6479012569400164, True),
#   (39, 2.4431071093259606, True),
#   (40, 3.3150149014706747, True),
#   (41, 2.3863221207983027, True),
#   (42, 1.2708886956484144, True),
#   (43, 1.4672104778583088, True),
#   (44, 2.0058460454803755, True),
#   (45, 1.4584187531961046, True),
#   (46, 1.9557147070873289, True),
#   (48, 1.70680865779765, True),
#   (50, 1.0881913104643557, True),
#   (51, 0.9864537929992934, True),
#   (52, 4.060124283169673, True),
#   (54, 3.0992335856624242, False),
#   (56, 3.5115398657101182, True),
#   (57, 1.2891899501747588, True),
#   (58, 0.8264311113199982, True),
#   (59, 1.346257551421909, True),
#   (60, -0.032072431667531376, True),
#   (62, -0.27261956162773915, True),
#   (63, 3.2927688495340215, True),
#   (64, 2.4938974046110762, True),
#   (65, 2.6988169405646123, True),
#   (66, 2.375416911338647, True),
#   (67, 1.3659354625452318, True),
#   (68, 1.322900749605446, True),
#   (69, 2.431516520684994, True),
#   (70, 1.2779984169974394, True),
#   (71, 1.6195153874161665, True),
#   (72, 2.3439456053976233, True),
#   (73, 1.2199816042686213, True),
#   (74, 1.9278691732007454, True),
#   (75, 1.5768290196450943, True),
#   (76, 2.6838256471725006, True),
#   (77, -1.0316444881805977, True),
#   (78, 1.8607733816094627, True),
#   (79, 2.6407585823526722, True),
#   (80, 1.2378119915563872, True),
#   (81, -0.29693028932254784, True),
#   (82, 2.407099792221942, True),
#   (83, 2.74373193858482, True),
#   (84, 1.2017553499225007, True),
#   (85, 2.500020772646511, True),
#   (86, 1.51976537887624, True),
#   (87, 1.3719458387404089, True),
#   (88, 0.937111298379226, True),
#   (89, 0.9541029224959268, True),
#   (90, 3.914838736440305, True),
#   (92, 1.732329694227645, True),
#   (93, -0.28362032753607425, True),
#   (94, 0.5307132748856025, True),
#   (95, 1.4081797018334425, True),
#   (96, 1.2171150789986105, True),
#   (97, 1.4244340981190393, True),
#   (98, 0.6603852452686356, True),
#   (99, 1.4390977983360953, True)]}

# %%
from copy import deepcopy


def get_ucb(estimate, n_total, n_pulled):
    return estimate + np.sqrt(2 * np.log(n_total) / n_pulled)


def get_new_estimate(estimate, n_pulled, pulled_value):
    return (estimate * n_pulled + pulled_value) / (n_pulled + 1)


def play_ucb(bandits, n_times):
    # Start with playing each bandit once
    pulled_values, results = [], []
    for bandit in bandits:
        pulled_value = bandit.draw()
        pulled_values.append(pulled_value)
    N = len(bandits)
    res = {i: {'n_pulled': 1, 'estimated_mean': pulled_values[i]} for i in range(len(bandits))}
    results.append(deepcopy(res))
    for i in range(n_times - len(bandits)):
        ucbs = np.array([get_ucb(v['estimated_mean'], N, v['n_pulled']) for v in res.values()])
        print(f'DEBUG: round {i}')
        print(f'DEBUG: ucbs: {ucbs}')
        selected_bandit = np.argmax(ucbs)
        print(f'DEBUG: selected_bandit: {selected_bandit}')
        pulled_value = bandits[selected_bandit].draw()
        new_estimate = get_new_estimate(res[selected_bandit]['estimated_mean'], res[selected_bandit]['n_pulled'],  pulled_value)
        res[selected_bandit]['estimated_mean'] = new_estimate
        res[selected_bandit]['n_pulled'] += 1
        results.append(deepcopy(res))
        print(f'res: {res}')
        N += 1
    return results

# %%
results_ucb = play_ucb(bandits, 100)
print(results_ucb)
# Out:
# DEBUG: round 0
# DEBUG: ucbs: [1.66593878 2.1507083  4.15282311]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 2, 'estimated_mean': 2.0433030149753435}}
# DEBUG: round 1
# DEBUG: ucbs: [1.8487442  2.33351371 3.22071304]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 3, 'estimated_mean': 2.16456111449142}}
# DEBUG: round 2
# DEBUG: ucbs: [1.97775755 2.46252707 3.20039827]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 4, 'estimated_mean': 1.9129539708886703}}
# DEBUG: round 3
# DEBUG: ucbs: [2.07665345 2.56142296 2.85946321]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 5, 'estimated_mean': 1.6898348440750284}}
# DEBUG: round 4
# DEBUG: ucbs: [2.15640468 2.64117419 2.57208428]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 2, 'estimated_mean': 1.0966287757863704}, 2: {'n_pulled': 5, 'estimated_mean': 1.6898348440750284}}
# DEBUG: round 5
# DEBUG: ucbs: [2.22296895 2.53865566 2.60185273]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 2, 'estimated_mean': 1.0966287757863704}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 6
# DEBUG: ucbs: [2.27992912 2.57893258 2.40189557]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 3, 'estimated_mean': 1.616021563326391}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 7
# DEBUG: ucbs: [2.329601   2.85499563 2.42217403]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 4, 'estimated_mean': 1.6086471229239652}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 8
# DEBUG: ucbs: [2.37356432 2.7036118  2.44012198]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 5, 'estimated_mean': 1.6269337633844168}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 9
# DEBUG: ucbs: [2.41294278 2.62391052 2.45619817]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 6, 'estimated_mean': 1.5798940229829546}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 10
# DEBUG: ucbs: [2.44856294 2.504547   2.47074004]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}
# DEBUG: round 11
# DEBUG: ucbs: [2.48104975 2.31581351 2.48400272]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 7, 'estimated_mean': 1.6918935778556778}}
# DEBUG: round 12
# DEBUG: ucbs: [2.51088666 2.3270908  2.57151203]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 8, 'estimated_mean': 1.921782858194383}}
# DEBUG: round 13
# DEBUG: ucbs: [2.53845502 2.33751066 2.75433747]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 9, 'estimated_mean': 1.9085401869296643}}
# DEBUG: round 14
# DEBUG: ucbs: [2.56406071 2.3471887  2.70201543]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 10, 'estimated_mean': 1.8554726607640735}}
# DEBUG: round 15
# DEBUG: ucbs: [2.58795265 2.35621901 2.61578467]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 11, 'estimated_mean': 1.8900891499098156}}
# DEBUG: round 16
# DEBUG: ucbs: [2.61033602 2.36467913 2.62176704]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 12, 'estimated_mean': 1.9486796415765182}}
# DEBUG: round 17
# DEBUG: ucbs: [2.6313818  2.37263369 2.65528329]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 13, 'estimated_mean': 1.9190766432884772}}
# DEBUG: round 18
# DEBUG: ucbs: [2.65123398 2.3801371  2.60346547]
# DEBUG: selected_bandit: 0
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 13, 'estimated_mean': 1.9190766432884772}}
# DEBUG: round 19
# DEBUG: ucbs: [1.65434414 2.38723561 2.60867435]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 14, 'estimated_mean': 1.7710002400592906}}
# DEBUG: round 20
# DEBUG: ucbs: [1.66694075 2.39396877 2.44027428]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 15, 'estimated_mean': 1.7778769958063934}}
# DEBUG: round 21
# DEBUG: ucbs: [1.67891776 2.40037075 2.42883054]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 16, 'estimated_mean': 1.899075535016481}}
# DEBUG: round 22
# DEBUG: ucbs: [1.69033065 2.4064712  2.53339366]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 17, 'estimated_mean': 1.7706509202488352}}
# DEBUG: round 23
# DEBUG: ucbs: [1.70122789 2.41229602 2.38976761]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 8, 'estimated_mean': 1.3082718978301147}, 2: {'n_pulled': 17, 'estimated_mean': 1.7706509202488352}}
# DEBUG: round 24
# DEBUG: ucbs: [1.71165206 2.21599389 2.39334307]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 8, 'estimated_mean': 1.3082718978301147}, 2: {'n_pulled': 18, 'estimated_mean': 1.782466870122837}}
# DEBUG: round 25
# DEBUG: ucbs: [1.72164076 2.22098824 2.39094443]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 8, 'estimated_mean': 1.3082718978301147}, 2: {'n_pulled': 19, 'estimated_mean': 1.7254716507565921}}
# DEBUG: round 26
# DEBUG: ucbs: [1.73122737 2.22578155 2.32083053]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 8, 'estimated_mean': 1.3082718978301147}, 2: {'n_pulled': 20, 'estimated_mean': 1.7063844433312467}}
# DEBUG: round 27
# DEBUG: ucbs: [1.74044162 2.23038867 2.2895823 ]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 8, 'estimated_mean': 1.3082718978301147}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 28
# DEBUG: ucbs: [1.74931012 2.23482292 2.19287658]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 9, 'estimated_mean': 1.4575538804500319}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 29
# DEBUG: ucbs: [1.75785678 2.3351435  2.19551414]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 10, 'estimated_mean': 1.4533120384669644}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 30
# DEBUG: ucbs: [1.76610314 2.28955453 2.19805902]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 11, 'estimated_mean': 1.435242020579867}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 31
# DEBUG: ucbs: [1.77406869 2.23596448 2.20051725]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 12, 'estimated_mean': 1.4855817932754878}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 32
# DEBUG: ucbs: [1.78177113 2.25535969 2.20289427]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 13, 'estimated_mean': 1.4887696624603715}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 33
# DEBUG: ucbs: [1.78922654 2.2312726  2.20519506]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 21, 'estimated_mean': 1.620996875123622}}
# DEBUG: round 34
# DEBUG: ucbs: [1.79644961 2.14274094 2.20742415]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 22, 'estimated_mean': 1.6678562522860958}}
# DEBUG: round 35
# DEBUG: ucbs: [1.80345377 2.14538827 2.24291247]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 23, 'estimated_mean': 1.6808582611094818}}
# DEBUG: round 36
# DEBUG: ucbs: [1.81025134 2.14795751 2.24527883]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 24, 'estimated_mean': 1.6808429091979749}}
# DEBUG: round 37
# DEBUG: ucbs: [1.81685365 2.15045295 2.23528553]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 25, 'estimated_mean': 1.7375448954416848}}
# DEBUG: round 38
# DEBUG: ucbs: [1.82327114 2.15287853 2.28260064]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 26, 'estimated_mean': 1.7191209012850313}}
# DEBUG: round 39
# DEBUG: ucbs: [1.82951343 2.15523789 2.25532333]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 27, 'estimated_mean': 1.7409656763400903}}
# DEBUG: round 40
# DEBUG: ucbs: [1.83558944 2.15753441 2.26879843]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 28, 'estimated_mean': 1.8146310807040211}}
# DEBUG: round 41
# DEBUG: ucbs: [1.84150744 2.1597712  2.33453421]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 29, 'estimated_mean': 1.826521873706407}}
# DEBUG: round 42
# DEBUG: ucbs: [1.84727508 2.16195117 2.33889717]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 30, 'estimated_mean': 1.8323392564365093}}
# DEBUG: round 43
# DEBUG: ucbs: [1.85289951 2.164077   2.33755481]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 31, 'estimated_mean': 1.8103543807276399}}
# DEBUG: round 44
# DEBUG: ucbs: [1.85838737 2.16615122 2.30874842]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 32, 'estimated_mean': 1.7959022328296852}}
# DEBUG: round 45
# DEBUG: ucbs: [1.86374486 2.16817616 2.28778643]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 33, 'estimated_mean': 1.7969005514141123}}
# DEBUG: round 46
# DEBUG: ucbs: [1.86897777 2.17015401 2.28256288]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 34, 'estimated_mean': 1.8174471194075108}}
# DEBUG: round 47
# DEBUG: ucbs: [1.87409154 2.17208683 2.29715432]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 35, 'estimated_mean': 1.8204435533144885}}
# DEBUG: round 48
# DEBUG: ucbs: [1.87909123 2.17397654 2.29444329]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 36, 'estimated_mean': 1.8299097794076091}}
# DEBUG: round 49
# DEBUG: ucbs: [1.88398163 2.17582494 2.2984325 ]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 37, 'estimated_mean': 1.7906042291612059}}
# DEBUG: round 50
# DEBUG: ucbs: [1.88876721 2.17763372 2.25386482]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 38, 'estimated_mean': 1.7823827331615412}}
# DEBUG: round 51
# DEBUG: ucbs: [1.89345218 2.17940447 2.24058196]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 39, 'estimated_mean': 1.8010956403311986}}
# DEBUG: round 52
# DEBUG: ucbs: [1.89804053 2.1811387  2.25442142]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 40, 'estimated_mean': 1.7651549965525295}}
# DEBUG: round 53
# DEBUG: ucbs: [1.90253598 2.18283782 2.21378356]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 41, 'estimated_mean': 1.7839201210522864}}
# DEBUG: round 54
# DEBUG: ucbs: [1.90694208 2.18450317 2.22801697]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 42, 'estimated_mean': 1.8072638756385957}}
# DEBUG: round 55
# DEBUG: ucbs: [1.91126217 2.18613601 2.24698473]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 43, 'estimated_mean': 1.788280907827082}}
# DEBUG: round 56
# DEBUG: ucbs: [1.91549939 2.18773753 2.22377247]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 44, 'estimated_mean': 1.8253781777443583}}
# DEBUG: round 57
# DEBUG: ucbs: [1.91965675 2.18930887 2.25677889]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 45, 'estimated_mean': 1.8478535873948958}}
# DEBUG: round 58
# DEBUG: ucbs: [1.92373708 2.19085108 2.27529423]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 46, 'estimated_mean': 1.8321755040115417}}
# DEBUG: round 59
# DEBUG: ucbs: [1.92774305 2.1923652  2.25577983]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 47, 'estimated_mean': 1.8456203880681776}}
# DEBUG: round 60
# DEBUG: ucbs: [1.93167724 2.19385218 2.26550562]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 48, 'estimated_mean': 1.8417045779929724}}
# DEBUG: round 61
# DEBUG: ucbs: [1.93554205 2.19531295 2.25798188]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 49, 'estimated_mean': 1.8301248487099369}}
# DEBUG: round 62
# DEBUG: ucbs: [1.9393398  2.19674836 2.24289979]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 50, 'estimated_mean': 1.834865702303209}}
# DEBUG: round 63
# DEBUG: ucbs: [1.94307268 2.19815926 2.24423862]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 51, 'estimated_mean': 1.825668761603439}}
# DEBUG: round 64
# DEBUG: ucbs: [1.94674279 2.19954643 2.23173514]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 52, 'estimated_mean': 1.8527463248611586}}
# DEBUG: round 65
# DEBUG: ucbs: [1.9503521  2.20091062 2.25559711]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 53, 'estimated_mean': 1.8377710778040275}}
# DEBUG: round 66
# DEBUG: ucbs: [1.95390253 2.20225256 2.23749299]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 54, 'estimated_mean': 1.8419469280107204}}
# DEBUG: round 67
# DEBUG: ucbs: [1.95739589 2.20357292 2.23862271]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 55, 'estimated_mean': 1.849089778680341}}
# DEBUG: round 68
# DEBUG: ucbs: [1.96083391 2.20487237 2.24279848]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 56, 'estimated_mean': 1.8401981019914884}}
# DEBUG: round 69
# DEBUG: ucbs: [1.96421825 2.20615153 2.23101529]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 57, 'estimated_mean': 1.8421375714087684}}
# DEBUG: round 70
# DEBUG: ucbs: [1.9675505  2.207411   2.23013556]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 58, 'estimated_mean': 1.8366979781136796}}
# DEBUG: round 71
# DEBUG: ucbs: [1.97083216 2.20865135 2.221946  ]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 14, 'estimated_mean': 1.4245171523013813}, 2: {'n_pulled': 59, 'estimated_mean': 1.823666808902456}}
# DEBUG: round 72
# DEBUG: ucbs: [1.97406469 2.20987313 2.20623122]
# DEBUG: selected_bandit: 1
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 59, 'estimated_mean': 1.823666808902456}}
# DEBUG: round 73
# DEBUG: ucbs: [1.97724948 2.19224751 2.20681759]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 60, 'estimated_mean': 1.8640985859060892}}
# DEBUG: round 74
# DEBUG: ucbs: [1.98038787 2.19339349 2.24461602]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 61, 'estimated_mean': 1.9023257757715317}}
# DEBUG: round 75
# DEBUG: ucbs: [1.98348113 2.19452299 2.28027142]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 62, 'estimated_mean': 1.9085632206013268}}
# DEBUG: round 76
# DEBUG: ucbs: [1.9865305  2.19563646 2.28399621]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 63, 'estimated_mean': 1.902448157459743}}
# DEBUG: round 77
# DEBUG: ucbs: [1.98953715 2.19673434 2.27542531]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 64, 'estimated_mean': 1.8859731960870731}}
# DEBUG: round 78
# DEBUG: ucbs: [1.99250222 2.19781703 2.25654915]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 65, 'estimated_mean': 1.8920462589099045}}
# DEBUG: round 79
# DEBUG: ucbs: [1.99542679 2.19888493 2.26027358]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 66, 'estimated_mean': 1.8821841774666526}}
# DEBUG: round 80
# DEBUG: ucbs: [1.99831192 2.19993843 2.24811349]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 67, 'estimated_mean': 1.8849093626518438}}
# DEBUG: round 81
# DEBUG: ucbs: [2.00115862 2.2009779  2.24858943]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 68, 'estimated_mean': 1.8727439288015566}}
# DEBUG: round 82
# DEBUG: ucbs: [2.00396784 2.20200368 2.23422175]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 69, 'estimated_mean': 1.8674134746495947}}
# DEBUG: round 83
# DEBUG: ucbs: [2.00674054 2.20301613 2.22673438]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 70, 'estimated_mean': 1.8672815566520728}}
# DEBUG: round 84
# DEBUG: ucbs: [2.0094776  2.20401556 2.2244893 ]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 71, 'estimated_mean': 1.8896276323337857}}
# DEBUG: round 85
# DEBUG: ucbs: [2.01217991 2.2050023  2.24476446]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 72, 'estimated_mean': 1.9052399098506194}}
# DEBUG: round 86
# DEBUG: ucbs: [2.01484829 2.20597666 2.25834661]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 73, 'estimated_mean': 1.9153812408034805}}
# DEBUG: round 87
# DEBUG: ucbs: [2.01748355 2.20693892 2.26649726]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 74, 'estimated_mean': 1.9318875036925796}}
# DEBUG: round 88
# DEBUG: ucbs: [2.02008648 2.20788938 2.28105096]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 75, 'estimated_mean': 1.9488250261851197}}
# DEBUG: round 89
# DEBUG: ucbs: [2.02265783 2.2088283  2.29607282]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 76, 'estimated_mean': 1.944511384508461}}
# DEBUG: round 90
# DEBUG: ucbs: [2.02519832 2.20975596 2.28987921]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 77, 'estimated_mean': 1.9812121045594169}}
# DEBUG: round 91
# DEBUG: ucbs: [2.02770866 2.2106726  2.32473453]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 78, 'estimated_mean': 1.9668724414169532}}
# DEBUG: round 92
# DEBUG: ucbs: [2.03018954 2.21157849 2.30858295]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 79, 'estimated_mean': 1.9563700208127226}}
# DEBUG: round 93
# DEBUG: ucbs: [2.03264159 2.21247385 2.29630107]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 80, 'estimated_mean': 1.9704126303175762}}
# DEBUG: round 94
# DEBUG: ucbs: [2.03506547 2.21335893 2.30859568]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 81, 'estimated_mean': 1.9571131994283633}}
# DEBUG: round 95
# DEBUG: ucbs: [2.03746179 2.21423394 2.29357876]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 82, 'estimated_mean': 1.9547650749764844}}
# DEBUG: round 96
# DEBUG: ucbs: [2.03983114 2.2150991  2.28954275]
# DEBUG: selected_bandit: 2
# res: {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 15, 'estimated_mean': 1.432358632282954}, 2: {'n_pulled': 83, 'estimated_mean': 1.9660288091815266}}
# [{0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 1, 'estimated_mean': 2.6705193074103515}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 2, 'estimated_mean': 2.0433030149753435}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 3, 'estimated_mean': 2.16456111449142}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 4, 'estimated_mean': 1.9129539708886703}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 1, 'estimated_mean': 0.6684044908869098}, 2: {'n_pulled': 5, 'estimated_mean': 1.6898348440750284}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 2, 'estimated_mean': 1.0966287757863704}, 2: {'n_pulled': 5, 'estimated_mean': 1.6898348440750284}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 2, 'estimated_mean': 1.0966287757863704}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 3, 'estimated_mean': 1.616021563326391}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 4, 'estimated_mean': 1.6086471229239652}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 5, 'estimated_mean': 1.6269337633844168}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 6, 'estimated_mean': 1.5798940229829546}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 6, 'estimated_mean': 1.5460870685625447}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 7, 'estimated_mean': 1.6918935778556778}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 8, 'estimated_mean': 1.921782858194383}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 9, 'estimated_mean': 1.9085401869296643}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 10, 'estimated_mean': 1.8554726607640735}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 11, 'estimated_mean': 1.8900891499098156}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 12, 'estimated_mean': 1.9486796415765182}}, {0: {'n_pulled': 1, 'estimated_mean': 0.1836349729126025}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 13, 'estimated_mean': 1.9190766432884772}}, {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 13, 'estimated_mean': 1.9190766432884772}}, {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 14, 'estimated_mean': 1.7710002400592906}}, {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pulled': 15, 'estimated_mean': 1.7778769958063934}}, {0: {'n_pulled': 2, 'estimated_mean': -0.10379192950715582}, 1: {'n_pulled': 7, 'estimated_mean': 1.447472344570675}, 2: {'n_pull ...

# %%
labels = list(results_ucb.keys())
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
# Out:
# 4.666666666666667
